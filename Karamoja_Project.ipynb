# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: MBALA TERRY SAMARA
# * Student pace: PART-TIME
# * Scheduled project review date/time:
# * Instructor name: VERONICA ISIAHO / SAMWEL JANE
# * Blog post URL:https://colab.research.google.com/drive/1Ef436ulLfGN3EBbmOwaC_vdARRqOipDe#scrollTo=BuglBVt3L3eh

# %% [markdown]
# #Business Problem

# %% [markdown]
# Karamoja region in Uganda comprises of eight districts (Kotido District, Kaabong District, Karenga District, Nabilatuk District, Abim District, Moroto District, Napak District, Amudat District and Nakapiripirit District) in the North Eastern part of Uganda.Unfortunately, it's one of the most food insecure regions.
#
# The districts of Karamoja have the highest Human Poverty Indices (HPI).Poverty is increasing and one of the main factors responsible for poverty is persistent poor harvest.
#
# Several NGO's provide technical support to farmers experiencing low yields. However, they lack visibility into the overall state of the region and often rely on some very local sources of information to conduct their work.
#
# Dalberg Data Insights needs to develop a strategy to remotely measure the yield of the two main staple crops of the Karamoja.

# %% [markdown]
# #Business Understanding

# %% [markdown]
# We need to find out:
#
# -What is the total maize and sorghum production in the region?
#
# -Can other crops be grown on the crop area?
#
# -Which staple food does better?
#
# -How much of the crop area bears yields?

# %% [markdown]
# #Previewing the data

# %%
#Importing the necessary libraries
import pandas as pd
import numpy as np

# %%
#Loading the first data
district_df = pd.read_csv('/content/Uganda_Karamoja_District_Crop_Yield_Population.csv')
#Loading the first 3 rows
district_df.head(3)
# Out:
#    OBJECTID     NAME     POP        Area  S_Yield_Ha  M_Yield_Ha  \
# 0        92     ABIM   90385  2771977106         449        1040
# 1        96   AMUDAT  101790  1643582836         205        1297
# 2        20  KAABONG  627057  7373606003         279         945
#
#    Crop_Area_Ha     S_Area_Ha    M_Area_Ha  S_Prod_Tot  M_Prod_Tot
# 0   5470.068394   3277.295971  1848.621855     1471506     1922567
# 1   5765.443719   2973.423860  2733.661014      609552     3545558
# 2  28121.672530  20544.194960  7394.416334     5731830     6987723

# %%
#Loading the second data set
sub_county_df = pd.read_csv('/content/Uganda_Karamoja_Subcounty_Crop_Yield_Population.csv')
#Loading the first 3 rows
sub_county_df.head(3)
# Out:
#    OBJECTID       SUBCOUNTY_NAME DISTRICT_NAME    POP        Area Karamoja  \
# 0       263              KACHERI        KOTIDO  17244  1067176155        Y
# 1       264               KOTIDO        KOTIDO  52771   597575188        Y
# 2       265  KOTIDO TOWN COUNCIL        KOTIDO  27389    23972401        Y
#
#    S_Yield_Ha   M_Yield_Ha  Crop_Area_Ha     S_Area_Ha   M_Area_Ha  \
# 0  354.207411  1137.467019   7023.533691   6434.342449  528.124229
# 1  367.890523  1162.996687  13587.990760  12455.592640  824.767081
# 2  369.314177  1167.005832   1656.531855   1520.322052    8.561644
#
#      S_Prod_Tot     M_Prod_Tot
# 0  2.279092e+06  600723.892900
# 1  4.582294e+06  959201.382500
# 2  5.614765e+05    9991.488268

# %%
#Viewing information about the district data set
district_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OBJECTID      7 non-null      int64
#  1   NAME          7 non-null      object
#  2   POP           7 non-null      int64
#  3   Area          7 non-null      int64
#  4   S_Yield_Ha    7 non-null      int64
#  5   M_Yield_Ha    7 non-null      int64
#  6   Crop_Area_Ha  7 non-null      float64
#  7   S_Area_Ha     7 non-null      float64
#  8   M_Area_Ha     7 non-null      float64
#  9   S_Prod_Tot    7 non-null      int64
#  10  M_Prod_Tot    7 non-null      int64
# dtypes: float64(3), int64(7), object(1)
# memory usage: 744.0+ bytes

# %%
#Viewing information about the sub county data set
sub_county_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OBJECTID        52 non-null     int64
#  1   SUBCOUNTY_NAME  52 non-null     object
#  2   DISTRICT_NAME   52 non-null     object
#  3   POP             52 non-null     int64
#  4   Area            52 non-null     int64
#  5   Karamoja        52 non-null     object
#  6   S_Yield_Ha      52 non-null     float64
#  7   M_Yield_Ha      52 non-null     float64
#  8   Crop_Area_Ha    52 non-null     float64
#  9   S_Area_Ha       52 non-null     float64
#  10  M_Area_Ha       52 non-null     float64
#  11  S_Prod_Tot      52 non-null     float64
#  12  M_Prod_Tot      52 non-null     float64
# dtypes: float64(7), int64(3), object(3)
# memory usage: 5.4+ KB

# %%
#Calculating statistical data about the district data set
district_df.describe()
# Out:
#         OBJECTID            POP          Area  S_Yield_Ha   M_Yield_Ha  \
# count   7.000000       7.000000  7.000000e+00    7.000000     7.000000
# mean   61.714286  214943.571429  3.960853e+09  269.285714   986.142857
# std    36.481567  188604.280916  1.781860e+09  119.243049   321.566700
# min     5.000000   90385.000000  1.643583e+09  128.000000   355.000000
# 25%    37.000000  114800.500000  3.171069e+09  171.000000   899.500000
# 50%    80.000000  146780.000000  3.641540e+09  279.000000  1040.000000
# 75%    88.500000  205391.000000  4.362553e+09  343.500000  1206.000000
# max    96.000000  627057.000000  7.373606e+09  449.000000  1297.000000
#
#        Crop_Area_Ha     S_Area_Ha    M_Area_Ha    S_Prod_Tot    M_Prod_Tot
# count      7.000000      7.000000     7.000000  7.000000e+00  7.000000e+00
# mean   21094.520379  16737.636651  3983.947082  4.873098e+06  4.085632e+06
# std    17363.854165  16625.963460  2678.911441  5.743724e+06  2.877188e+06
# ...

# %%
##Calculating statistical data about the sub county data set
sub_county_df.describe()
# Out:
#           OBJECTID            POP          Area  S_Yield_Ha   M_Yield_Ha  \
# count    52.000000      52.000000  5.200000e+01   52.000000    52.000000
# mean    787.865385   28934.692308  5.331913e+08  274.165405   940.259552
# std     280.101314   20865.122974  4.913308e+08  118.569907   321.641901
# min     263.000000    1418.000000  2.121209e+06  108.156411     0.000000
# 25%     597.750000   16558.500000  1.568923e+08  173.034066   743.075879
# 50%     810.500000   23053.500000  3.848356e+08  277.255206  1016.684002
# 75%     982.250000   39461.000000  7.749029e+08  368.246437  1203.548665
# max    1320.000000  100919.000000  2.069555e+09  560.313070  1396.991494
#
#        Crop_Area_Ha     S_Area_Ha    M_Area_Ha    S_Prod_Tot    M_Prod_Tot
# count     52.000000     52.000000    52.000000  5.200000e+01  5.200000e+01
# mean    2839.646974   2253.143395   536.300569  6.557443e+05  5.500730e+05
# std     3110.505917   2954.355858   724.092288  9.915839e+05  7.939707e+05
# ...

# %% [markdown]
# #Data Cleaning

# %% [markdown]
# ##Changing column names format

# %% [markdown]
# Some column names have been capitalised.Let's change that.

# %%
#Converting the capitalised column names in to title case
district_df.columns=district_df.columns.str.strip().str.title()
#Checking whether they've changed
district_df.head(2)
# Out:
#    Objectid    Name     Pop        Area  S_Yield_Ha  M_Yield_Ha  Crop_Area_Ha  \
# 0        92    ABIM   90385  2771977106         449        1040   5470.068394
# 1        96  AMUDAT  101790  1643582836         205        1297   5765.443719
#
#      S_Area_Ha    M_Area_Ha  S_Prod_Tot  M_Prod_Tot
# 0  3277.295971  1848.621855     1471506     1922567
# 1  2973.423860  2733.661014      609552     3545558

# %%
#Converting the capitalised column names in to title case
sub_county_df.columns=sub_county_df.columns.str.strip().str.title()
#Checking whether they've changed
sub_county_df.head(2)
# Out:
#    Objectid Subcounty_Name District_Name    Pop        Area Karamoja  \
# 0       263        KACHERI        KOTIDO  17244  1067176155        Y
# 1       264         KOTIDO        KOTIDO  52771   597575188        Y
#
#    S_Yield_Ha   M_Yield_Ha  Crop_Area_Ha     S_Area_Ha   M_Area_Ha  \
# 0  354.207411  1137.467019   7023.533691   6434.342449  528.124229
# 1  367.890523  1162.996687  13587.990760  12455.592640  824.767081
#
#     S_Prod_Tot   M_Prod_Tot
# 0  2279091.779  600723.8929
# 1  4582294.492  959201.3825

# %% [markdown]
# ##Adding a column for total yield in hectares

# %%
#Adding a new column
sub_county_df['Total_Yield_Ha'] = sub_county_df['S_Yield_Ha'] + sub_county_df['M_Yield_Ha']
#Checking whether the column has been added
sub_county_df.head(2)
# Out:
#    Objectid Subcounty_Name District_Name    Pop        Area Karamoja  \
# 0       263        KACHERI        KOTIDO  17244  1067176155        Y
# 1       264         KOTIDO        KOTIDO  52771   597575188        Y
#
#    S_Yield_Ha   M_Yield_Ha  Crop_Area_Ha     S_Area_Ha   M_Area_Ha  \
# 0  354.207411  1137.467019   7023.533691   6434.342449  528.124229
# 1  367.890523  1162.996687  13587.990760  12455.592640  824.767081
#
#     S_Prod_Tot   M_Prod_Tot  Total_Yield_Ha
# 0  2279091.779  600723.8929      1491.67443
# 1  4582294.492  959201.3825      1530.88721

# %% [markdown]
# ##Checking for null values

# %%
#Checking for null values
district_df.isnull().sum()
# Out:
# Objectid        0
# Name            0
# Pop             0
# Area            0
# S_Yield_Ha      0
# M_Yield_Ha      0
# Crop_Area_Ha    0
# S_Area_Ha       0
# M_Area_Ha       0
# S_Prod_Tot      0
# M_Prod_Tot      0
# dtype: int64

# %%
sub_county_df.isnull().sum()
# Out:
# Objectid          0
# Subcounty_Name    0
# District_Name     0
# Pop               0
# Area              0
# Karamoja          0
# S_Yield_Ha        0
# M_Yield_Ha        0
# Crop_Area_Ha      0
# S_Area_Ha         0
# M_Area_Ha         0
# S_Prod_Tot        0
# M_Prod_Tot        0
# Total_Yield_Ha    0
# dtype: int64

# %% [markdown]
# There are no null values in both data sets

# %% [markdown]
# ##Checking for duplicate values

# %%
#Checking for duplicate values
district_df.duplicated().sum()
# Out:
# 0

# %%
#Checking for duplicate values
sub_county_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate values

# %% [markdown]
# #Data Visualization

# %% [markdown]
# The visuals have been conducted on another space known as Tableau Public. They can be accessed via the READ.ME on Github where this notebook has been accessed. The graphs show a clear depiction and representation of the data.

# %% [markdown]
# #Findings

# %% [markdown]
# From the visuals made on Tableau Public, we can conclude that:
#
# -Maize does generally better than sorghum.
#
# -Kaabong district does relatively better than the other districts.
#
# -84,512 hectares of the crop area doesn't bear yield.
#
# -Kaabong district has the most yields for both sorghum and maize

# %% [markdown]
# #Recommendations

# %% [markdown]
# -Increase productivity of sorghum in Amudat District.
#
# -Increase productivity of maize in Moroto District.
#
# -Plant other crops that can do well in the 84,512 hectares of land.
